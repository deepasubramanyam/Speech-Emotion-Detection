# %%
import keras
from keras.utils import plot_model

restored_keras_model = keras.models.load_model("C:\\model\\Emotion_Voice_Detection_Model.h5")
plot_model(restored_keras_model, to_file='model.png')
